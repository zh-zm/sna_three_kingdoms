# %% [markdown]
# ## Preparing data

# %% [markdown]
# Loading the text from websites.
# Then splitting text into paragraphs

# %%
import requests
from bs4 import BeautifulSoup

def load_split_text(url):
    '''Load the text from the website, and split text into paragraphs'''
    raw_data = requests.get(url)
    assert raw_data.status_code == 200
    soup = BeautifulSoup(raw_data.text, 'html5lib')
    post = soup.find_all('div', {'class': 'lacontent'})[0]
    text = post.get_text()
    paragraphs = [paragraph for paragraph in text.split('\n') if len(paragraph)>0]
    return paragraphs

chapters = []
for i in range(595996,596116):
    url = 'http://www.guoxuemeng.com/guoxue/' + str(i) + '.html'
    chapters.append(load_split_text(url))

# %% [markdown]
# Named entity recognition using spacy.
# Extracting the characters of the novel.

# %%
import spacy
import re

NLP = spacy.load('en_core_web_sm')
name_re = re.compile(r"[A-Z][a-z]* [A-Z][a-z]*$")
name_re_genitive = re.compile(r"[A-Z][a-z]* [A-Z][a-z]*'s")

people_by_chapters = []
for chapter in chapters:
    people_by_paragraphs = []
    for paragraph in chapter:
        people_one_paragraph = []
        doc = NLP(paragraph)
        for ent in doc.ents:
            if str(ent.label_) == 'PERSON':
                if re.match(name_re, str(ent)):
                    people_one_paragraph.append(str(ent))
                elif re.match(name_re_genitive, str(ent)):
                    people_one_paragraph.append(str(ent)[:-2])
        if len(people_one_paragraph)>0:
            people_by_paragraphs.append(people_one_paragraph)
    people_by_chapters.append(people_by_paragraphs)

# %%
people_by_chapters[0]
# Out:
# [['Liu Bang', 'Wang Mang', 'Liu Xiu'],
#  ['Emperor Huan',
#   'Emperor Ling',
#   'Chen Fan',
#   'Dou Wu',
#   'Chen Fan',
#   'Dou Wu',
#   'Chen Fan'],
#  ['Emperor Ling'],
#  ['Emperor Ling'],
#  ['Cai Yong'],
#  ['Cao Jie', 'Cai Yong'],
#  ['Zhang Rang',
#   'Zhao Zhong',
#   'Cheng Kuang',
#   'Duan Gui',
#   'Feng Xu',
#   'Guo Sheng',
#   'Hou Lan',
#   'Jian Shuo',
#   'Cao Jie',
#   'Xia Yun'],
#  ['Zhang Rang'],
#  ['Zhang Jiao',
#   'Zhang Ba',
#   'Zhang Lian',
#   'Zhang Jiao',
#   'Zhang Jiao',
#   'Zhang Jiao'],
#  ['Zhang Jiao'],
#  ['Saint Hermit'],
#  ['Zhang Jiao'],
#  ['Zhang Jiao'],
#  ['Zhang Jiao'],
#  ['Zhang Jiao', 'Ma Yuanyi'],
#  ['Zhang Jiao'],
#  ['Zhang Jiao', 'Tang Zhou', 'He Jin', 'Ma Yuanyi', 'Feng Xu'],
#  ['Zhang Jiao', 'Zhang Ba'],
#  ['Worthy Man'],
#  ['Zhang Jiao'],
#  ['Lu Zhi', 'Huangfu Song', 'Zhu Jun'],
#  ['Zhang Jiao', 'Liu Yan', 'Liu Yan', 'Zhou Jing'],
#  ['Zhou Jing'],
#  ['Liu Yan'],
#  ['Liu Bei', 'Liu Hong', 'Liu Bei'],
#  ['Liu Bei'],
#  ['Liu Bei', 'Liu Yuanqi', 'Liu Bei'],
#  ['Liu Bei', 'Zheng Xuan', 'Lu Zhi'],
#  ['Liu Bei'],
#  ['Liu Bei'],
#  ['Liu Bei'],
#  ['Zhang Fei'],
#  ['Liu Bei'],
#  ['Liu Bei', 'Liu Bei'],
#  ['Guan Yu'],
#  ['Liu Bei', 'Guan Yu', 'Zhang Fei'],
#  ['Liu Bei', 'Guan Yu'],
#  ['Liu Bei', 'Guan Yu', 'Zhang Fei'],
#  ['Liu Bei', 'Zhang Fei'],
#  ['Liu Bei'],
#  ['Zhang Shiping', 'Su Shuang', 'Liu Bei', 'Zhang Shiping', 'Su Shuang'],
#  ['Liu Bei', 'Guan Yu', 'Zhang Fei'],
#  ['Zhou Jing', 'Liu Yan', 'Liu Yan'],
#  ['Cheng Yuanzhi', 'Liu Yan', 'Zhou Jing', 'Liu Bei'],
#  ['Liu Bei', 'Guan Yu', 'Zhang Fei'],
#  ['Liu Bei'],
#  ['Cheng Yuanzhi',
#   'Deng Mao',
#   'Zhang Fei',
#   'Deng Mao',
#   'Cheng Yuanzhi',
#   'Zhang Fei',
#   'Guan Yu',
#   'Cheng Yuanzhi'],
#  ['Zhou Jing'],
#  ['Liu Bei', 'Lu Zhi', 'Zhang Jiao', 'Lu Zhi'],
#  ['Liu Bei', 'Zhou Jing', 'Lu Zhi'],
#  ['Zhang Jiao', 'Lu Zhi'],
#  ['Lu Zhi', 'Liu Bei', 'Zhang Ba', 'Zhang Lian', 'Huangfu Song', 'Zhu Jun'],
#  ['Liu Bei'],
#  ['Huangfu Song', 'Zhu Jun'],
#  ['Huangfu Song', 'Zhu Jun'],
#  ['Zhang Lian', 'Zhang Ba', 'Cao Cao', 'Cao Song', 'Cao Song'],
#  ['Cao Cao'],
#  ['Cao Cao'],
#  ['Cao Cao'],
#  ['Qiao Xuan', 'Cao Cao'],
#  ['Cao Cao', 'Xu Shao'],
#  ['Cao Cao'],
#  ['Cao Cao'],
#  ['Xu Shao'],
#  ['Cao Cao', 'Cao Cao'],
#  ['Cao Cao', 'Zhang Ba', 'Zhang Lian', 'Huangfu Song', 'Cao Cao'],
#  ['Liu Bei', 'Huangfu Song', 'Zhu Jun', 'Lu Zhi'],
#  ['Zhang Jiao'],
#  ['Lu Zhi', 'Liu Bei'],
#  ['Lu Zhi', 'Zhang Jiao', 'Dong Zhuo'],
#  ['Zhang Fei', 'Lu Zhi', 'Liu Bei'],
#  ['Liu Bei'],
#  ['Guan Yu', 'Zhang Jiao'],
#  ['Liu Bei'],
#  ['Zhang Jiao', 'Dong Zhuo'],
#  ['Dong Zhuo'],
#  ['Dong Zhuo', 'Liu Bei', 'Zhang Fei'],
#  ['Zhang Fei'],
#  ['Zhang Fei', 'Dong Zhuo'],
#  ['Zhang Fei'],
#  ['Dong Zhuo']]

# %% [markdown]
# Getting list of names of all characters

# %%
people_all = []
for people_by_paragraphs in people_by_chapters:
    for people_one_paragraph in people_by_paragraphs:
        people_all += people_one_paragraph
        
people_all_set = set(people_all)

# %%
len(people_all_set)
# Out:
# 1460

# %%
people_all_set
# Out:
# {'Zuo Xian',
#  'Zhang Liang',
#  'Rear Guards',
#  'Su Dongpo',
#  'Zuo Ling',
#  'Han Xian',
#  'Yi Yin',
#  'Huan Jie',
#  'Zhou Fang',
#  'Zhou Yafu',
#  'Han Xin',
#  'Hua Xin',
#  'Zhang Hua',
#  'Lu Lu',
#  'Lu Gong',
#  'Gong Qi',
#  'Lu Chang',
#  'Sun Kan',
#  'Liu Dan',
#  'Zhao Zhong',
#  'Cao Rui',
#  'Marching Generals',
#  'Zhang Liao',
#  'Mi Dang',
#  'River Gannan',
#  'Yang Song',
#  'Sun Gong',
#  'Chen Ji',
#  'Sima Hui',
#  'Wang Yun',
#  'Wang Lang',
#  'Hearing Xuzhou',
#  'Pang Shu',
#  'Zhang Hui',
#  'Wu Zilan',
#  'Liu Hu',
#  'Zhang Ti',
#  'Wu Gang',
#  'Hu Miao',
#  'Pang Degong',
#  'Duan Wei',
#  'Yang Qiu',
#  'Gao Shun',
#  'Emperor Pi',
#  'Ma Yu',
#  'Wang Jian',
#  'Huang Zhong',
#  'Du Xi',
#  'Yang Qun',
#  'Liu He',
#  'Li Hu',
#  'Jia Kui',
#  'Zhao Cen',
#  'Suffering Defeat',
#  'Yang Fang',
#  'Huan Fan',
#  'Sima Shi',
#  'Zhang Rang',
#  'Ling Tong',
#  'Xu Yun',
#  'Han Hao',
#  'Wu Jing',
#  'Ma Yun',
#  'Kui Gu',
#  'Master Kuang',
#  'Deng Xian',
#  'Tao Qian',
#  'Yu Ji',
#  'Qu Yi',
#  'Ma Miao',
#  'Marches The',
#  'Xue Xu',
#  'Wherefore Confucius',
#  'Si Fan',
#  'Cao Shen',
#  'Hu Zhong',
#  'Peng Ji',
#  'Zheng Xuan',
#  'Wei Xu',
#  'Chang Xi',
#  'Duke Huan',
#  'Sheng Bo',
#  'Shu Qi',
#  'Li Sheng',
#  'Wen Chou',
#  'Wang Xun',
#  'Capital Luoyang',
#  'Yu Quan',
#  'Jiang Yan',
#  'Xu Shu',
#  'Hua Yong',
#  'Liu Xia',
#  'Huang Fu',
#  'Yuan Tan',
#  'Teng Yin',
#  'Guo Tu',
#  'Shi Kuang',
#  'Hu Juer',
#  'Meng Gongwei',
#  'Fu Ying',
#  'Feng Xu',
#  'Zhang Wu',
#  'Zhao Tong',
#  'Song Guo',
#  'Zhang Jue',
#  'River Fu',
#  'Meng Tian',
#  'Shen Zong',
#  'Kuai Yue',
#  'Yang Zong',
#  'Xun Zheng',
#  'Zong Bao',
#  'Prince Huan',
#  'Yang Hu',
#  'King Yao',
#  'Lady Li',
#  'Sima You',
#  'Li Gui',
#  'Zhou Yu',
#  'Zhang Pu',
#  'Chen Fan',
#  'Liu Biao',
#  'Wu Yi',
#  'Sun Hao',
#  'Bian Rang',
#  'Ding Feng',
#  'Yuan Wei',
#  'Li Xian',
#  'Yang Xiong',
#  'Hu Zong',
#  'White Dress',
#  'Dragon Courage',
#  'Chen Sun',
#  'Wuhuan Chu',
#  'Court Counselor',
#  'Quan Duan',
#  'Huang Hao',
#  'Hou Lan',
#  'Zheng Lun',
#  'Su Shuang',
#  'Ning Sui',
#  'Sun Deng',
#  'Peng Bo',
#  'Xu Zhi',
#  'Zhang Jie',
#  'Wang Ye',
#  'Lu Xun',
#  'Ma Zhong',
#  'Guo Si',
#  'Sun Li',
#  'Sui Lie',
#  'Han Song',
#  'Bei Yan',
#  'Lady Wu',
#  'Cheng Pu',
#  'Zhu Zan',
#  'Xi Zheng',
#  'Wang Shen',
#  'Zhong Yao',
#  'Lurking Dragon',
#  'Liu Fei',
#  'Sun Xi',
#  'Liu Dai',
#  'Zuo Ci',
#  'Zhang Si',
#  'Wei Miao',
#  'Cao Amin',
#  'Zhang Shiping',
#  'Shen Pei',
#  'Xia Yun',
#  'Xiahou Hui',
#  'Zhang Zi',
#  'Yellow Dawn',
#  'Yuan Shao',
#  'Deng Cheng',
#  'Jiao Yi',
#  'Meng Crosses',
#  'Liu Shi',
#  'Liang Ji',
#  'Yan Hui',
#  'Sun Yi',
#  'Liu Zong',
#  'Sun Shao',
#  'Yang Hong',
#  'Lu Yu',
#  'Zhu Zhi',
#  'Hu Zhen',
#  'Mi Fang',
#  'Wen Zhong',
#  'Yin Chun',
#  'Zhang Nan',
#  'Wang Su',
#  'Zhou Fan',
#  'Sleeping Dragon',
#  'Ding Fei',
#  'Wang Kuang',
#  'Bo Shou',
#  'Quan Ji',
#  'Jiang Yiqu',
#  'Zhong Captures',
#  "Cao Cao'sï",
#  'Shisun Rui',
#  'Qiao Rui',
#  'Lady Cui',
#  'Hou Cao',
#  'Huo Guang',
#  'Lu Bu',
#  'Cao Xi',
#  'Wang Mang',
#  'Quan Zong',
#  'Zhuge Xuan',
#  'Liu Xiangru',
#  'Zang Min',
#  'Gao Gan',
#  'Liu Fu',
#  'Cao Xun',
#  'Liu Mao',
#  'Ge Ding',
#  'Su Qin',
#  'Wang Lian',
#  'Xiao Pass',
#  'Wei Jiang',
#  'Dong He',
#  'Shi Zuan',
#  'Xu Shang',
#  'Cao Teng',
#  'Wang Jun',
#  'Zhao Hong',
#  'Wang Zhi',
#  'Gao Sheng',
#  'Sun Ji',
#  'Xu Chu',
#  'Tian Du',
#  'Saint Hermit',
#  'Liu Lian',
#  'Meng You',
#  'Chunyu Dan',
#  'Emperor Yi',
#  'Zhou Ying',
#  'Zhang Xiang',
#  'Ou Xing',
#  'Dragon Ridge',
#  'Yi Ji',
#  'Liu Pi',
#  'Ding Mi',
#  'Yan Yu',
#  'Cui Yong',
#  'Wang Tao',
#  'Hu Fen',
#  'Breaks Faith',
#  'Chou Lian',
#  'Song Qian',
#  'Guo Chang',
#  'Peng Yue',
#  'Wang Jing',
#  'Wang Fu',
#  'Bo Yi',
#  'Soon Zhang',
#  'Zhange Fei',
#  'Ehe Shaoge',
#  'Sun Jun',
#  'Han Rong',
#  'Cen Zhi',
#  'Chen Xiang',
#  'Fu Zha',
#  'Liu Ping',
#  'Liang Kuan',
#  'Bao Long',
#  'Emperor Xian',
#  'Diao Chan',
#  'Lady Zhi',
#  'Yang Ling',
#  'Sun Ju',
#  'White Horses',
#  'Van Leaders',
#  'Li Zong',
#  'Yang Zuo',
#  'Cuan Xi',
#  'Zhou Ping',
#  'Zhang Jian',
#  'Zhang Ni',
#  'Zhu Ran',
#  'Who Establishes',
#  'Emperor Cao',
#  'Bao Su',
#  'Zhao Qu',
#  'Qin Mi',
#  'Quoting Confucius',
#  'Sun Liang',
#  'Jin Yi',
#  'Guan Neng',
#  'Zhou Bi',
#  'Sun Yin',
#  'Tao Jun',
#  'Empress Fu',
#  'Guan Lu',
#  'Xun Xu',
#  'Capital Changan',
#  'Shi Guangyuan',
#  'Cheng Ji',
#  'He Miao',
#  'Zhuge Zhan',
#  'Yang Xiu',
#  'Tang Zi',
#  'Chen Lin',
#  'Zhang Heng',
#  'Ren Kui',
#  'Zhuge Gui',
#  'Liao Chun',
#  'Shu Kingdom',
#  'Yin Shang',
#  'Fan Jian',
#  'Xue Zong',
#  'Dou Wu',
#  'Qu Yuan',
#  'Zhang Zifang',
#  'Liang Gang',
#  'Hu Hua',
#  'Han Juzi',
#  'Wang Kai',
#  'Lu Zhi',
#  'Yan Guang',
#  'Liu Ning',
#  'Yuan Xing',
#  'Xu Sheng',
#  'Yuan Yi',
#  'Li Yiji',
#  'Pan Yin',
#  'Sima Zhou',
#  'Xu Liu',
#  'Xun You',
#  'Zhang Ming',
#  'Li Yan',
#  'Meng Zong',
#  'Yang Huai',
#  'Pang Juan',
#  'Chong Huang',
#  'Zuo Botao',
#  'Hao Zhao',
#  'Sima Fu',
#  'Xu Yan',
#  'Guo En',
#  'Quan Shang',
#  'Liu Qi',
#  'Sun Chen',
#  'Lu Kuang',
#  'Cheng Dechen',
#  'Yan Liang',
#  'Wang Han',
#  'Zhang Zhu',
#  'Shamo Ke',
#  'Xi Shi',
#  'Du Biao',
#  'Zhao Yang',
#  'Li Deng',
#  'Yang Ji',
#  'Heir Apparent',
#  'Liu Zhang',
#  'Liu Gui',
#  'Xie Valley',
#  'Guo Sheng',
#  'Han Qu',
#  'Liu Fang',
#  'Lu Boshe',
#  'Jue Attacks',
#  'Zhao Yun',
#  'Huang Wan',
#  'Zhu Yi',
#  'Hu Yuan',
#  'Han Zhong',
#  'Zhang Te',
#  'Gui Lan',
#  'Xie Xiong',
#  'Zhu Huan',
#  'Yun Ying',
#  'Bao Xin',
#  'Ma Liang',
#  'Empress He',
#  'Dragon Throne',
#  'Wang Chun',
#  'Wonderful Prince',
#  'Zhang Ling',
#  'Dong Xi',
#  'Xin Xianying',
#  'Worthy Man',
#  'Red Hare',
#  'Cao Xiong',
#  'Lu Kai',
#  'Gao Kai',
#  'Jia Fan',
#  'Shen Rong',
#  'Yu She',
#  'Sima Yi',
#  'Ma Yan',
#  'King Zhao',
#  'Zhou Jing',
#  'Cen Hun',
#  'Rear Guard',
#  'Bu Zhi',
#  'Zhong Yu',
#  'Liu Da',
#  'Lu Jing',
#  'Duke Wen',
#  'Cheng Jin',
#  'Jiao Chu',
#  'Zheng Wen',
#  'Chi Lu',
#  'Dong Yun',
#  'Hou Yi',
#  'Li Su',
#  'Yang Bo',
#  'Wu Qi',
#  'Qin Liang',
#  'Gongsun Zan',
#  'Song Zhong',
#  'Yin Kui',
#  'Pan Zhang',
#  'Tang Bin',
#  'Tian Chou',
#  'Zuo Volume',
#  'Lu Meng',
#  'Wherefore Jingzhou',
#  'Lu Zhao',
#  'Cao Jie',
#  'Wherefore Zhang',
#  'Xia Xun',
#  'Xue Rong',
#  'Ling Bao',
#  'Lady Wang',
#  'Sun Huan',
#  'Mu Lu',
#  'Zhang Xi',
#  'Pang Rou',
#  'Liang Xu',
#  'Wen Ping',
#  'Zong Yu',
#  'Jian Shuo',
#  'Wu Zixu',
#  'Zuo Qiuming',
#  'Wei Kai',
#  'Yang Feng',
#  'Consort Dong',
#  'Cheng Deshu',
#  'Lu Kuai',
#  'Xu Si',
#  'Who Conquers',
#  'Guan Zhong',
#  'Cui Yu',
#  'Who Wrecks',
#  'Xiahou Ying',
#  'Pang Tong',
#  'Ding Li',
#  'Fu Tong',
#  'Mi Heng',
#  'Yao Qi',
#  'Marching Commanders',
#  'Jiang Qin',
#  'Zhang Jun',
#  'Li Teng',
#  'Li Tong',
#  'Yang Fu',
#  'Cao Shuang',
#  'Lady Kai',
#  'Yuan Xi',
#  'Zhuge Feng',
#  'Pan Jun',
#  'Guan Yong',
#  'Liu Xiong',
#  'Zhu En',
#  'Hua Xiong',
#  'Cao Zun',
#  'Zhang Ju',
#  'Qin Lang',
#  'Cao Ju',
#  'Lian Po',
#  'Huang Chong',
#  'Bai Juyi',
#  'Lu Qian',
#  'He Yan',
#  'Liu Jun',
#  'Zhang Ba',
#  'Xiahou Wei',
#  'Gongsun Yuan',
#  'Establishes Anyi',
#  'Lady Cao',
#  'Wang Chang',
#  'Zheng Tai',
#  'Fei Yao',
#  'Shang Dynasty',
#  'Song Xian',
#  'Cheng Zu',
#  'Prince Gong',
#  'Zhang Su',
#  'Deng Liang',
#  'Sun Kuang',
#  'Yue Ji',
#  'Hu Ji',
#  'Emperor Huan',
#  'Liu Xiang',
#  'Murong Lie',
#  'Hu Ban',
#  'Wen Yang',
#  'Guo Jian',
#  'Hu Cai',
#  'Lady Hu',
#  'Wu Dun',
#  'Cui Zhouping',
#  'Prince Xiang',
#  'Sima Zhao',
#  'Zhang Jiao',
#  'Hu Zhi',
#  'Min Gong',
#  'Bing Yuan',
#  'Chen Ying',
#  'Mao Dun',
#  'Wutu Gu',
#  'Cai Yong',
#  'Dong Cao',
#  'Cao Fang',
#  'Xu Huan',
#  'Zhi Xi',
#  'Zhao Zuo',
#  'Lu Zhu',
#  'Han Dynasty',
#  'Li Zhuan',
#  'Lu Jun',
#  'Jiang Ji',
#  'Who Upholds',
#  'Kuai Liang',
#  'Ren Jun',
#  'Cheng Bing',
#  'Lady Wuyan',
#  'Xiahou Lan',
#  'Zhuge Qian',
#  'Wang Zhao',
#  'Liu Xi',
#  'Shao Yuan',
#  'Geng Ji',
#  'Universal Earth',
#  'Lu Yin',
#  'Meng Jie',
#  'Yang Yong',
#  'Xu Zi',
#  'Wei Yin',
#  'Yong Kai',
#  'Jinhua Sanjie',
#  'Xiahou Mao',
#  'Yu Jin',
#  'Sun Wan',
#  'Wang Yi',
#  'Han Ying',
#  'Shi Yu',
#  'Pu Jing',
#  'Dong Xun',
#  'Sima Yan',
#  'Sun Qiao',
#  'Lu Gang',
#  'Wu Huo',
#  'Guanqiu Dian',
#  'Ju Shou',
#  'Wang Fang',
#  'Han Yao',
#  'Qin Qi',
#  'Xiahou Dun',
#  'Yue Chen',
#  'Zhuo Ying',
#  'Jizhou Taken',
#  'Sun Zu',
#  'Yue Jiu',
#  'Emperor Ling',
#  'Guan Ning',
#  'Sang Hongyang',
#  'Lu Wang',
#  'Dong Min',
#  'Dian Man',
#  'Empress Dong',
#  'Zhang Chao',
#  'Mao Jie',
#  'Hou Cheng',
#  'Hu Chier',
#  'Tai Jia',
#  'Xiahou Xian',
#  'Han Fu',
#  'Xu Huang',
#  'Zhang Xian',
#  'Qian Hong',
#  'Liu Lu',
#  'Ma Tie',
#  'Capital Jianye',
#  'Liu Shao',
#  'Zhao Fan',
#  'Ju Gu',
#  'Tu An',
#  'Fan Kang',
#  'Pei Xu',
#  'Zhang Kai',
#  'Cheng Yuanzhi',
#  'Zhang Shang',
#  'Zhang Yi',
#  'Feng Fang',
#  'Zhang Qi',
#  'Xue Yong',
#  'Sima Wang',
#  'Cao De',
#  'Liu Yue',
#  'Cai Lin',
#  'Ursa Minor',
#  'Cao Yan',
#  'Ding Yuan',
#  'Lai Gong',
#  'Lady Qiao',
#  'Fan Zeng',
#  'Yang Qi',
#  'Lady He',
#  'Ding Yin',
#  'Yangping Pass',
#  'Zhang Da',
#  'Zhuge Jing',
#  'Liu Yan',
#  'Yue Jing',
#  'Ma Dai',
#  'Wei Ping',
#  'Liu Xue',
#  'Liu Zi',
#  'Prince Xian',
#  'Liu Xian',
#  'Duke Zhou',
#  'Wang Guan',
#  'Jiang Gan',
#  'Yuan Shang',
#  'Yan Baihu',
#  'Ma Jun',
#  'Zhuge Xing',
#  'Chen Wei',
#  'Zhang Qiu',
#  'River Luo',
#  'Yue Fei',
#  'Sun Xin',
#  'Dong Huang',
#  'Zhang Miao',
#  'He Ping',
#  'Wei Yan',
#  'Qiu Jian',
#  'Shi Bao',
#  'Zhao Yue',
#  'Zhou Cai',
#  'Liu Yang',
#  'Noble Sirs',
#  'The King',
#  'Yan Pu',
#  'Transverse Peace',
#  'Zhao Rong',
#  'Bai Qi',
#  'Gao Ding',
#  'Chunyu Qiong',
#  'Zheng Du',
#  'River Lu',
#  'Zhang Hong',
#  'Saber Pass',
#  'Yu Shao',
#  'Ma Han',
#  'Yan Zheng',
#  'Cao Hong',
#  'Tang Zhou',
#  'Li Gu',
#  'Zhu Ling',
#  'Sima Liang',
#  'Wang Yan',
#  'Wu Pass',
#  'Worthy Ministers',
#  'Guan Xing',
#  'Wu Yang',
#  'Lady Pan',
#  'Lu Xu',
#  'Guan Chun',
#  'Who Wages',
#  'Cen Bi',
#  'Fei Yi',
#  'Li Dian',
#  'Ge Yong',
#  'Ma Yuanyi',
#  'Xiahou He',
#  'Wang Hou',
#  'Liu Zhong',
#  'Lou Zibo',
#  'Wu Fu',
#  'Lady Qiong',
#  'Jin Dynasty',
#  'Taishi Ci',
#  'Yu Rang',
#  'Ji Mao',
#  'Xia Yu',
#  'Dragon General',
#  'Du Qiong',
#  'Liu Chan',
#  'Cao Xu',
#  'Cen Wei',
#  'Hua Jiao',
#  'Gu Li',
#  'Cao Mao',
#  'Pang De',
#  'Liu Jian',
#  'Lu Kui',
#  'Li Ru',
#  'Lady Liu',
#  'Tiandang Mountain',
#  'Li Du',
#  'Zhou Yin',
#  'Wu Anguo',
#  'Lun Zhi',
#  'Chen Shi',
#  'Liu Shan',
#  'Guan Suo',
#  'Wu Shi',
#  'Zhang Bu',
#  'Huguan Pass',
#  'Xu Chang',
#  'Manifest Might',
#  'Sima Fang',
#  'Deng Mao',
#  'Mangya Chang',
#  'Ma Su',
#  'Tan Xiong',
#  'Gou Jian',
#  'Ma Zun',
#  'Cypress Beams',
#  'Kings Yu',
#  'River Ji',
#  'Lady Zhao',
#  'Xun Yu',
#  'Shi Huan',
#  'Cheng Wu',
#  'Jia Hua',
#  'Zhang Jing',
#  'Wu Can',
#  'Zhou Dynasty',
#  'Tian Guang',
#  'Huang Shao',
#  'Li Fang',
#  'Meng Da',
#  'Emperor Jing',
#  'River Yao',
#  'Fu Wan',
#  'Cai Yan',
#  'Bu Chan',
#  'Niu Jin',
#  'Qiao Mao',
#  'Cao Xiu',
#  'Zhou Xun',
#  'Huang Gai',
#  'Xiahou Xuan',
#  'Yangjue Ai',
#  'Gong Gong',
#  'Zhou Huan',
#  'Daisy Pavilion',
#  'Dong Zhou',
#  'Liu Du',
#  'Guo Ye',
#  'Lady Zhurong',
#  'Jia Yi',
#  'Latter Ruler',
#  'Feng Li',
#  'Luo Guanzhong',
#  'Wang Liang',
#  'Zhong Hui',
#  'Wen Shu',
#  'Du Qi',
#  'Supernumerary Leader',
#  'Wang Qin',
#  'Liang Qian',
#  'Han De',
#  'Zhang Xiu',
#  'Fang Yue',
#  'Liu Tao',
#  'Guan Yu',
#  'Wang Mai',
#  'Xiao He',
#  'Sun Jian',
#  'Quin Quington',
#  'Lady Bian',
#  'Chen Lan',
#  'Sun Jing',
#  'Xing Darong',
#  'Wu Yan',
#  'River Xicheng',
#  'Duke Xiao',
#  'Su Xian',
#  'Wang Ping',
#  'Chief Commanders',
#  'Yang Mi',
#  'Zhang Cheng',
#  'Zhou Shan',
#  'Liu Ai',
#  'Guan Ding',
#  'Geng Gong',
#  'Xu Rong',
#  'Yang Yi',
#  'Dong Chong',
#  'Yuan Dynasty',
#  'Zhang Yang',
#  'Lu Xiang',
#  'Yuan Shu',
#  'Sima Jun',
#  'Zhou Bo',
#  'Sima Juan',
#  'Kong Rong',
#  'Xia Dynasty',
#  'Shan Fu',
#  'Zhang Wen',
#  'Wu Ju',
#  'Li Xin',
#  'Duo Si',
#  'Zhang Han',
#  'Zhang Yan',
#  'Empress Zhang',
#  'Zhang Lian',
#  'Zhuge Xu',
#  'Wang Zhong',
#  'Sweet Dew',
#  'Dai Ling',
#  'Lu Fan',
#  'Cao E',
#  'Wei Kang',
#  'Jin Shang',
#  'Zhuge Zhang',
#  'Jiang Xiong',
#  'Liu An',
#  'Jiang Wei',
#  'Yu Gong',
#  'Ji Ling',
#  'Wang Chan',
#  'Xiang Chong',
#  'Liu Zang',
#  'Tian Xu',
#  'King Yu',
#  'Yang Chou',
#  'Wei Zi',
#  'Commanding Adviser',
#  'Liu Yuanqi',
#  'Cai Zhong',
#  'Han Sui',
#  'Sima Qian',
#  'Zhang Mao',
#  'Sun Hu',
#  'Zhang Wan',
#  'Lady Yan',
#  'Yin Damu',
#  'Jade Dragon',
#  'Ahui Nan',
#  'Han Qiong',
#  'Zi Fan',
#  'Yan Jun',
#  'Mi Zhu',
#  'Zhao Qi',
#  'Fu Xuan',
#  'Lai Min',
#  'Chen Deng',
#  'Pan Sui',
#  'Meng Ben',
#  'Yan Xiang',
#  'Lu Jia',
#  'Zhang Chun',
#  'Du Mao',
#  'Pei Xiu',
#  'Lady Xun',
#  'Xu Gong',
#  'Tiger Lust',
#  'Li Qu',
#  'Yan Ren',
#  'Ding Fung',
#  'Ce Xian',
#  'Xiang Yu',
#  'Lu Weihuang',
#  'Chong Ji',
#  'Xiping Pass',
#  'Wang Can',
#  'Li Lou',
#  'Chen Yuan',
#  'Tian Zhang',
#  'Cao Ren',
#  'Kong Yu',
#  'Tian Feng',
#  'Yan Yan',
#  'Sun Ren',
#  'Wei Hong',
#  'Gu Yong',
#  'Xu Jing',
#  'Ma Xiu',
#  'Gou An',
#  'Xue Ti',
#  'Bian Que',
#  'Liu Hong',
#  'Zhang Zhao',
#  'Zheng Yu',
#  'Yuan Lin',
#  'Lady Xu',
#  'Dong Cheng',
#  'Liu Chang',
#  'Lei Xu',
#  'Qiu Ben',
#  'Gentlemen Scholars',
#  'He Zong',
#  'Shang Guang',
#  'Bo Le',
#  'Zhu Guang',
#  'Zheng Bao',
#  'Zhang Ji',
#  'Sun Guan',
#  'Fan Li',
#  'Zhang Yue',
#  'Yang Lin',
#  'Xun Kai',
#  'Shi Ji',
#  'Wang Wei',
#  'Zhang Mi',
#  'Wonderful Sight',
#  'Teng Xun',
#  'Lady Guo',
#  'Sun Quan',
#  'Yu Song',
#  'Bing Ji',
#  'Kebi Neng',
#  'Li Yi',
#  'Chen Gong',
#  'Liu Li',
#  'Li Chunxiang',
#  'Jin Xiang',
#  'Cao Yong',
#  'Lady Tang',
#  'Yuan Weizhi',
#  'Bian Hong',
#  'Xun Shen',
#  'Fan Chong',
#  'Chen Jiu',
#  'Ma Yuan',
#  'Liu Xiu',
#  'Zhong Jing',
#  'Shan Tao',
#  'Wang Kang',
#  'Cheng Yin',
#  'Shen Dan',
#  'Cen Peng',
#  'Huo Yi',
#  'Ya Dan',
#  'Yin Feng',
#  'Sun He',
#  'Zhang Shao',
#  'Lady Wuyang',
#  'Xiang Ba',
#  'Qiao Zhou',
#  'Ma Zheng',
#  'Zhao Zi',
#  'Ren Zuo',
#  'Jiao Bing',
#  'Pang Xi',
#  'Yang Dajiang',
#  'Sun Wu',
#  'Jiang Xu',
#  'Chong Fu',
#  'Hu Zun',
#  'Zang Cang',
#  'Jiang Qi',
#  'Lu Chan',
#  'Xue Ze',
#  'Mu Shun',
#  'Zeng Xuan',
#  'Xiahou Ba',
#  'Array Battles',
#  'Ying Bu',
#  'Marquis Tiger',
#  'Liu Zhan',
#  'Zhang Zun',
#  'Bowang Slope',
#  'Yun Rescues',
#  'Empress Wu',
#  'Dong Xin',
#  'He Yi',
#  'Hua Tuo',
#  'Xie Jing',
#  'Dragon Ruler',
#  'Huangfu Li',
#  'Lu Yi',
#  'Kou Feng',
#  'Ziwu Valley',
#  'Zhang Wei',
#  'Lady Ding',
#  'Fei Guan',
#  'Liu Che',
#  'Dong Chao',
#  'Sun Xiu',
#  'Ma Wan',
#  'Tan Fu',
#  'Nearing Jingzhou',
#  'Lu Cui',
#  'Lady Yang',
#  'Lady Xiahou',
#  'Wei Guan',
#  'Xiaoyao Ford',
#  'Dian Wei',
#  'Han Heng',
#  ...}

# %% [markdown]
# Extracting the social network of the Romance of the Three Kingdoms.
# This is a weighted undirected network.
# Characters are viewd as nodes, and the relationships among them — edges.
# If two characters occur in the same paragraph, then they are thought to have some relationship, i.e., edge will be built between these two nodes.
# The frequencies of co-occurence are the weights of edges.
# The social network of each chapter will be written into separate csv file.

# %%
#build pairs of characters

def build_pairs(people):
    people_couples = []
    for person_1 in people:
        for person_2 in people:
            if person_1 != person_2:
                people_couples.append(frozenset([person_1, person_2]))
    people_couples = set(people_couples)
    return people_couples

# %%
people_couples_all = build_pairs(people_all_set)

# %%
len(people_couples_all)
# Out:
# 1065070

# %% [markdown]
# Extracting social networks by checking if pairs of characters occur in the same paragraph.
# Writting social networks of each chapters into csv files.

# %%
import csv

for i in range(1, 121):
    edge_list = []
    for couple in people_couples_all:
        couple = list(couple)
        count = 0
        for people_one_paragraph in people_by_chapters[i-1]:
            if couple[0] in people_one_paragraph and couple[1] in people_one_paragraph:
                count += 1
        if count>0:
            edge_list.append([couple[0], couple[1], count])
        
    filename = 'romance_edge_list_' + str(i) + '.csv'
    f = open(filename,'w',newline='', encoding = 'utf-8')
    writer = csv.writer(f)
    for row in edge_list:
        writer.writerow(row)
    f.close()

# %% [markdown]
# See what we get

# %%
import pandas as pd

chapter_1_df = pd.read_csv('romance_edge_list_1.csv', names=['person 1', 'person 2', 'weight'])
chapter_1_df.head()
# Out:
#        person 1      person 2  weight
# 0  Huangfu Song       Zhu Jun       5
# 1     Jian Shuo       Hou Lan       1
# 2  Emperor Huan  Emperor Ling       1
# 3       Xia Yun       Hou Lan       1
# 4    Zheng Xuan        Lu Zhi       1

# %% [markdown]
# ## Network analysis for the whole book

# %%
import networkx as nx

def combine_networks_of_chapters(beg, end):
    '''
    This function combines networks of several chapters into one graph.
    It accepts two parameters: the number of the beginning chapter, and the number of the end chapter.
    '''
    G_chapters = []
    for i in range(beg, end+1):
        G0 = nx.read_weighted_edgelist('romance_edge_list_'+str(i)+'.csv', delimiter=',', nodetype=str, encoding='utf-8')
        G_chapters.append(G0)

    G_combined = nx.Graph()
    for G0 in G_chapters:
        for (u,v) in G0.edges:
            if G_combined.has_edge(u,v):
                G_combined[u][v]["weight"] += G0[u][v]["weight"]
            else:
                G_combined.add_edge(u,v,weight=G0[u][v]["weight"])
                
    return G_combined

# %% [markdown]
# Building the social network for the whole romance

# %%
G_all = combine_networks_of_chapters(1, 120)

# %% [markdown]
# General information

# %%
print('Number of nodes:', G_all.number_of_nodes())
print('Number of edges:', G_all.number_of_edges())
print('Number of connected components:', nx.number_connected_components(G_all))
print('Network density:', nx.density(G_all))
# Out:
# Number of nodes: 1389
# Number of edges: 8738
# Number of connected components: 12
# Network density: 0.009064635059742771

# %%
# we only need the giant connected component

largest = max(nx.connected_components(G_all),key=len)
G_all = G_all.subgraph(largest).copy()

print('Number of nodes:', G_all.number_of_nodes())
print('Number of edges:', G_all.number_of_edges())
print('Number of connected components:', nx.number_connected_components(G_all))
print('Network density:', nx.density(G_all))
# Out:
# Number of nodes: 1359
# Number of edges: 8702
# Number of connected components: 1
# Network density: 0.00943039421908815

# %% [markdown]
# Distance measures

# %%
print('Average shortest path length:', nx.average_shortest_path_length(G_all))
print('Diameter:', nx.diameter(G_all))
#print('Eccentricity:', nx.eccentricity(G_all))
print('Radius:', nx.radius(G_all))
print('Centers:', nx.center(G_all))
# Out:
# Average shortest path length: 3.0118687287390777
# Diameter: 8
# Radius: 4
# Centers: ['Liu Bei', 'Cao Cao', 'Zhang Fei', 'Guan Yu', 'Cheng Pu', 'Cao Hong', 'Cao Ren', 'Han Dang', 'Huang Gai', 'Zhao Yun', 'Sun Quan', 'Han Sui', 'Ma Teng', 'Liu Ye', 'Mi Zhu', 'Zhang Liao', 'Sun Qian', 'Xu Huang', 'Zhou Yu', 'Zhang Lu', 'River Huai', 'Jian Yong', 'Cao Pi']

# %% [markdown]
# ### Checking if this network has empirical network features

# %% [markdown]
# Power law

# %%
import matplotlib.pyplot as plt
import numpy as np

degrees_dictionary = dict(G_all.degree())
degrees = np.array(list(dict(G_all.degree()).values()))

# show node degrees
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 8))

axs[0].set_xlabel('Degrees')
axs[0].set_ylabel('Number')
axs[0].hist(degrees, 40)

from collections import Counter

d = Counter(degrees)

axs[1].set_xlabel('Degrees')
axs[1].set_ylabel('Number')
axs[1].loglog(list(d.keys()), list(d.values()), '.', lw=2)

plt.show()

# %% [markdown]
# Small world

# %% [markdown]
# Distances distribution

# %%
shortest_paths = nx.shortest_path(G_all)
lengths = []
for target, paths in shortest_paths.items():
    for k, value in paths.items():
        lengths.append(len(value))

fig, ax = plt.subplots(figsize=(10, 7))
ax.hist(lengths, 5)
ax.set_xlabel('Distances')
ax.set_ylabel('Number')

plt.show()

# %%
print('Average clustering coefficient:', nx.average_clustering(G_all))
print('Global clustering coefficient: ', nx.transitivity(G_all))
# Out:
# Average clustering coefficient: 0.6693551748893263
# Global clustering coefficient:  0.21474754081863695

# %% [markdown]
# 节点度分布符合真实世界中的幂律分布。
# 最短路径分布符合真实世界中的小世界理论。
# 但聚类系数却非常地低。这可能反映了三国演义的宏大叙事文本风格：并不像其它小说那样只围绕着几个主角和配角来写，而是更像一部史书，提及了这一历史阶段众多历史人物，从而导致了其较低的聚类系数。

# %% [markdown]
# ### Visualizing the whole network

# %% [markdown]
# There are some many nodes and edges in this graph. We have to select the most nodes better visualization.

# %%
G_all_main = nx.k_core(G_all, k=20).copy()
G_all_main.number_of_nodes()
# Out:
# 119

# %%
# Draw graph with varying node color, node size, and edge width
fig, ax = plt.subplots(figsize=(15, 9))

node_color = [2*G_all_main.degree(v) for v in G_all_main] #根据节点度上色
node_size = [10*G_all_main.degree(v) for v in G_all_main] #根据节点度调大小
edge_width = [0.05*G_all_main[u][v]['weight'] for u,v in G_all_main.edges()] #根据边的权重调粗细
pos = nx.spring_layout(G_all_main)
nx.draw_networkx(G_all_main, pos, 
                 node_color=node_color, 
                 node_size=node_size, 
                 alpha=1, with_labels=False, 
                 width=edge_width, edge_color='.4', cmap=plt.cm.Blues)
ax.axis('off')
fig.tight_layout()

# %% [markdown]
# ### Rankings by centralities

# %%
# Ranking by pagerank
import pandas as pd
     
fig, ax = plt.subplots(figsize=(13,8))
between = pd.Series(nx.pagerank(G_all)).sort_values()
between.tail(20).plot(kind="barh")
ax.set_xlabel('Ranking by PageRank')
plt.show()

# %% [markdown]
# PageRank: 主要人物

# %%
# Ranking by betweennes centrality

fig, ax = plt.subplots(figsize=(13,8))
between = pd.Series(nx.betweenness_centrality(G_all)).sort_values()
between.tail(20).plot(kind="barh")
ax.set_xlabel('Ranking by betweennes centrality')
plt.show()

# %% [markdown]
# Betweennes centrality：可以反映出人物的权力值。对比PageRank，可以看出，司马懿司马昭、还有袁绍和董卓等主公排名上升明显。

# %%
#Ranking by degree centrality

fig, ax = plt.subplots(figsize=(13,8))
between = pd.Series(nx.degree_centrality(G_all)).sort_values()
between.tail(20).plot(kind="barh")
ax.set_xlabel('Ranking by degree centrality')
plt.show()

# %%
#Ranking by closeness centrality

fig, ax = plt.subplots(figsize=(13,8))
between = pd.Series(nx.closeness_centrality(G_all_main)).sort_values()
between.tail(20).plot(kind="barh")
ax.set_xlabel('Ranking by closeness centrality')
plt.show()

# %%
#Ranking by eigenvector centrality

fig, ax = plt.subplots(figsize=(13,8))
between = pd.Series(nx.eigenvector_centrality(G_all_main)).sort_values()
between.tail(20).plot(kind="barh")
ax.set_xlabel('Ranking by eigenvector centrality')
plt.show()

# %% [markdown]
# Eigenvector centrality：特征向量中心度高的点的周围的点特征向量中心度也高。在其他排名中具有碾压优势的曹操在此排名中被刘备和诸葛亮超车。说明作者对蜀国的着墨较多，把很多主要人物放到了蜀国。
# 还有在各排名中，吴国的人排名都较低，说明吴国在这本书里面其实只是个配角，主角是魏蜀。

# %% [markdown]
# Bridges

# %%
nx.has_bridges(G_all_main)
# Out:
# False

# %% [markdown]
# 社区检测

# %%
from networkx.algorithms import community
from community import community_louvain

# Louvain's community detection method
def detect_communities_louvain(G):
    partition = community_louvain.best_partition(G)
    communities = list()
    for com in set(partition.values()) :
        list_nodes = [nodes for nodes in partition.keys() if partition[nodes] == com]
        communities.append(sorted(list_nodes))
    return sorted(communities)

# mod
def greedy_modularity_communities(G):
    communities = community.greedy_modularity_communities(G)
    print(communities)
    return sorted(map(sorted, communities))

# Girvan Newman's community detection method
def detect_communities_girvan_newman(G):
    communities = community.girvan_newman(G)
    return sorted(sorted(c) for c in next(communities))

# Fast Greedy community detection method
def detect_communities_greedy(G):
    communities = greedy_modularity_communities(G)
    return sorted(map(sorted, communities))

# Label propagation community detection method
def detect_communities_label_propagation(G):
    communities = list()
    #for c in asyn_lpa_communities(G):
    for c in label_propagation_communities(G):
        communities.append(sorted(c))
    return sorted(communities)

# %%
# Plot graph with communities, receives a list of communities, where each community is a list of nodes (ints)
def show_communities(G, communities):
    
    colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w', 'b', 'g', 'r', 'c', 'm', 'y', 'k', 'w', 'b', 'g', 'r', 'c', 'm', 'y', 'k', 'w', 'b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']
    fig, ax = plt.subplots(figsize=(15,9))
    aux = 0
    pos=nx.spring_layout(G)
    for community in communities:
        nx.draw_networkx_nodes(G, pos, community, alpha=0.7, node_size = 200, node_color = colors[aux])
        aux = aux + 1
    edge_width = [0.05*G[u][v]['weight'] for u,v in G.edges()]
    nx.draw_networkx_edges(G, pos, alpha=0.5, width=edge_width, edge_color='.4')
    fig.tight_layout()
    plt.show()

# %%
coms = detect_communities_louvain(G_all_main)
for com in coms:
    print(com)
show_communities(G_all_main, coms)
# Out:
# ['Cao Cao', 'Cao Hong', 'Cao Pi', 'Cao Ren', 'Cheng Yu', 'Dong Zhuo', 'Guo Jia', 'Guo Si', 'Jia Xu', 'Li Dian', 'Liu Biao', 'Liu Xiu', 'Liu Ye', 'Lu Bu', 'Lu Qian', 'Ma Chao', 'Ma Teng', 'Man Chong', 'Mao Jie', 'Pang De', 'Wen Ping', 'Xiahou Dun', 'Xiahou Yuan', 'Xu Chu', 'Xu Huang', 'Xun Yu', 'Yu Jin', 'Yuan Shao', 'Yuan Shu', 'Yue Jing', 'Zhang He', 'Zhang Liao', 'Zhang Xiu']
# ['Cao Xiu', 'Cao Zhen', 'Guan Xing', 'Guo Huai', 'Hu Ban', 'Jiang Wan', 'Jiang Wei', 'Liao Hua', 'Ma Dai', 'Ma Su', 'River Wei', 'Sima Yi', 'Wang Lang', 'Wang Ping', 'Wei Yan', 'Wu Yi', 'Yangping Pass', 'Zhang Bao', 'Zhang Yi', 'Zhuge Liang']
# ['Chen Wu', 'Cheng Pu', 'Ding Feng', 'Dong Xi', 'Gan Ning', 'Han Dang', 'Huang Gai', 'Jiang Qin', 'Ling Tong', 'Lu Fan', 'Lu Meng', 'Lu Su', 'Lu Xun', 'Pan Zhang', 'Sun Ce', 'Sun Quan', 'Taishi Ci', 'Van Leader', 'Xu Sheng', 'Zhang Zhao', 'Zhou Tai', 'Zhou Yu', 'Zhuge Jin']
# ['Deng Zhi', 'Dong He', 'Fa Zheng', 'Fei Guan', 'Fei Shi', 'Fei Yi', 'Huang Quan', 'Huo Jun', 'Lei Tong', 'Li Hui', 'Li Yan', 'Liu Ba', 'Liu Zhang', 'Lu Yin', 'Meng Da', 'Peng Yang', 'Qiao Zhou', 'Qin Mi', 'Wu Lan', 'Xu Jing', 'Yan Yan', 'Yang Hong', 'Zhang Lu', 'Zhou Qun', 'Zhuo Ying']
# ['Guan Ping', 'Guan Yu', 'Huang Zhong', 'Jiameng Pass', 'Jian Yong', 'Liu Bei', 'Liu Feng', 'Ma Liang', 'Mi Fang', 'Mi Zhu', 'Sun Qian', 'Who Conquers', 'Who Guards', 'Who Wages', 'Yi Ji', 'Zhang Fei', 'Zhao Yun', 'Zhou Cang']

# %%
coms = detect_communities_girvan_newman(G_all_main)
for com in coms:
    print(com)
show_communities(G_all_main, coms)
# Out:
# ['Cao Cao', 'Cao Hong', 'Cao Pi', 'Cao Ren', 'Cao Xiu', 'Cao Zhen', 'Chen Wu', 'Cheng Pu', 'Cheng Yu', 'Ding Feng', 'Dong Xi', 'Dong Zhuo', 'Gan Ning', 'Guan Ping', 'Guan Xing', 'Guan Yu', 'Guo Huai', 'Guo Jia', 'Guo Si', 'Han Dang', 'Hu Ban', 'Huang Gai', 'Huang Zhong', 'Jia Xu', 'Jiameng Pass', 'Jian Yong', 'Jiang Qin', 'Jiang Wan', 'Jiang Wei', 'Li Dian', 'Liao Hua', 'Ling Tong', 'Liu Bei', 'Liu Biao', 'Liu Feng', 'Liu Xiu', 'Liu Ye', 'Liu Zhang', 'Lu Bu', 'Lu Fan', 'Lu Meng', 'Lu Qian', 'Lu Su', 'Lu Xun', 'Ma Chao', 'Ma Dai', 'Ma Liang', 'Ma Su', 'Ma Teng', 'Man Chong', 'Mao Jie', 'Mi Fang', 'Mi Zhu', 'Pan Zhang', 'Pang De', 'River Wei', 'Sima Yi', 'Sun Ce', 'Sun Qian', 'Sun Quan', 'Taishi Ci', 'Van Leader', 'Wang Lang', 'Wang Ping', 'Wei Yan', 'Wen Ping', 'Who Conquers', 'Who Guards', 'Who Wages', 'Xiahou Dun', 'Xiahou Yuan', 'Xu Chu', 'Xu Huang', 'Xu Sheng', 'Xun Yu', 'Yangping Pass', 'Yi Ji', 'Yu Jin', 'Yuan Shao', 'Yuan Shu', 'Yue Jing', 'Zhang Bao', 'Zhang Fei', 'Zhang He', 'Zhang Liao', 'Zhang Lu', 'Zhang Xiu', 'Zhang Zhao', 'Zhao Yun', 'Zhou Cang', 'Zhou Tai', 'Zhou Yu', 'Zhuge Jin', 'Zhuge Liang']
# ['Deng Zhi', 'Dong He', 'Fa Zheng', 'Fei Guan', 'Fei Shi', 'Fei Yi', 'Huang Quan', 'Huo Jun', 'Lei Tong', 'Li Hui', 'Li Yan', 'Liu Ba', 'Lu Yin', 'Meng Da', 'Peng Yang', 'Qiao Zhou', 'Qin Mi', 'Wu Lan', 'Wu Yi', 'Xu Jing', 'Yan Yan', 'Yang Hong', 'Zhang Yi', 'Zhou Qun', 'Zhuo Ying']

# %%
coms = detect_communities_greedy(G_all_main)
for com in coms:
    print(com)
show_communities(G_all_main, coms)
# Out:
# [frozenset({'Cheng Pu', 'Han Dang', 'Zhang Lu', 'Xiahou Dun', 'Liu Zhang', 'Lu Bu', 'Yuan Shu', 'Sun Ce', 'Ling Tong', 'Zhang Zhao', 'Zhou Tai', 'Jiang Wei', 'Xu Chu', 'Taishi Ci', 'Liu Ye', 'Dong Xi', 'Yue Jing', 'Zhou Yu', 'Yu Jin', 'Man Chong', 'Xiahou Yuan', 'Guo Jia', 'Liu Xiu', 'Xu Sheng', 'Liu Biao', 'Lu Qian', 'Mao Jie', 'Jiang Qin', 'Dong Zhuo', 'Jia Xu', 'Pang De', 'Lu Su', 'Wen Ping', 'Zhang Liao', 'Zhuge Liang', 'Van Leader', 'Cao Xiu', 'Sun Quan', 'Xu Huang', 'Chen Wu', 'Ding Feng', 'Cao Cao', 'Cao Pi', 'Lu Xun', 'Huang Gai', 'Yuan Shao', 'Pan Zhang', 'Cao Ren', 'Zhang Xiu', 'Cheng Yu', 'Gan Ning', 'Lu Fan', 'Guan Yu', 'Guo Si', 'Ma Teng', 'Lu Meng', 'Li Dian', 'Cao Hong', 'Xun Yu', 'Zhuge Jin', 'Wang Lang'}), frozenset({'Cao Zhen', 'Yangping Pass', 'Ma Liang', 'Mi Zhu', 'Guan Ping', 'Jiang Wan', 'Meng Da', 'Zhang Yi', 'Liu Feng', 'Zhang Fei', 'Ma Dai', 'Ma Su', 'Guan Xing', 'Zhao Yun', 'Wu Yi', 'Mi Fang', 'Jiameng Pass', 'River Wei', 'Guo Huai', 'Sun Qian', 'Wang Ping', 'Ma Chao', 'Huang Zhong', 'Zhang He', 'Zhang Bao', 'Yi Ji', 'Jian Yong', 'Who Guards', 'Who Wages', 'Liao Hua', 'Hu Ban', 'Wei Yan', 'Who Conquers', 'Sima Yi', 'Zhou Cang'}), frozenset({'Wu Lan', 'Fei Guan', 'Lu Yin', 'Lei Tong', 'Zhuo Ying', 'Liu Bei', 'Qin Mi', 'Huo Jun', 'Deng Zhi', 'Yan Yan', 'Fei Yi', 'Xu Jing', 'Liu Ba', 'Fa Zheng', 'Dong He', 'Huang Quan', 'Qiao Zhou', 'Li Hui', 'Yang Hong', 'Fei Shi', 'Li Yan', 'Peng Yang', 'Zhou Qun'})]
# ['Cao Cao', 'Cao Hong', 'Cao Pi', 'Cao Ren', 'Cao Xiu', 'Chen Wu', 'Cheng Pu', 'Cheng Yu', 'Ding Feng', 'Dong Xi', 'Dong Zhuo', 'Gan Ning', 'Guan Yu', 'Guo Jia', 'Guo Si', 'Han Dang', 'Huang Gai', 'Jia Xu', 'Jiang Qin', 'Jiang Wei', 'Li Dian', 'Ling Tong', 'Liu Biao', 'Liu Xiu', 'Liu Ye', 'Liu Zhang', 'Lu Bu', 'Lu Fan', 'Lu Meng', 'Lu Qian', 'Lu Su', 'Lu Xun', 'Ma Teng', 'Man Chong', 'Mao Jie', 'Pan Zhang', 'Pang De', 'Sun Ce', 'Sun Quan', 'Taishi Ci', 'Van Leader', 'Wang Lang', 'Wen Ping', 'Xiahou Dun', 'Xiahou Yuan', 'Xu Chu', 'Xu Huang', 'Xu Sheng', 'Xun Yu', 'Yu Jin', 'Yuan Shao', 'Yuan Shu', 'Yue Jing', 'Zhang Liao', 'Zhang Lu', 'Zhang Xiu', 'Zhang Zhao', 'Zhou Tai', 'Zhou Yu', 'Zhuge Jin', 'Zhuge Liang']
# ['Cao Zhen', 'Guan Ping', 'Guan Xing', 'Guo Huai', 'Hu Ban', 'Huang Zhong', 'Jiameng Pass', 'Jian Yong', 'Jiang Wan', 'Liao Hua', 'Liu Feng', 'Ma Chao', 'Ma Dai', 'Ma Liang', 'Ma Su', 'Meng Da', 'Mi Fang', 'Mi Zhu', 'River Wei', 'Sima Yi', 'Sun Qian', 'Wang Ping', 'Wei Yan', 'Who Conquers', 'Who Guards', 'Who Wages', 'Wu Yi', 'Yangping Pass', 'Yi Ji', 'Zhang Bao', 'Zhang Fei', 'Zhang He', 'Zhang Yi', 'Zhao Yun', 'Zhou Cang']
# ['Deng Zhi', 'Dong He', 'Fa Zheng', 'Fei Guan', 'Fei Shi', 'Fei Yi', 'Huang Quan', 'Huo Jun', 'Lei Tong', 'Li Hui', 'Li Yan', 'Liu Ba', 'Liu Bei', 'Lu Yin', 'Peng Yang', 'Qiao Zhou', 'Qin Mi', 'Wu Lan', 'Xu Jing', 'Yan Yan', 'Yang Hong', 'Zhou Qun', 'Zhuo Ying']

# %%
coms = detect_communities_label_propagation(G_all_main)
for com in coms:
    print(com)
show_communities(G_all_main, coms)
# Out:
# ['Cao Cao', 'Cao Hong', 'Cao Pi', 'Cao Ren', 'Cao Xiu', 'Cao Zhen', 'Chen Wu', 'Cheng Pu', 'Cheng Yu', 'Deng Zhi', 'Ding Feng', 'Dong He', 'Dong Xi', 'Dong Zhuo', 'Fa Zheng', 'Fei Guan', 'Fei Shi', 'Fei Yi', 'Gan Ning', 'Guan Ping', 'Guan Xing', 'Guan Yu', 'Guo Huai', 'Guo Jia', 'Guo Si', 'Han Dang', 'Hu Ban', 'Huang Gai', 'Huang Quan', 'Huang Zhong', 'Huo Jun', 'Jia Xu', 'Jiameng Pass', 'Jian Yong', 'Jiang Qin', 'Jiang Wan', 'Jiang Wei', 'Lei Tong', 'Li Dian', 'Li Hui', 'Li Yan', 'Liao Hua', 'Ling Tong', 'Liu Ba', 'Liu Bei', 'Liu Biao', 'Liu Feng', 'Liu Xiu', 'Liu Ye', 'Liu Zhang', 'Lu Bu', 'Lu Fan', 'Lu Meng', 'Lu Qian', 'Lu Su', 'Lu Xun', 'Lu Yin', 'Ma Chao', 'Ma Dai', 'Ma Liang', 'Ma Su', 'Ma Teng', 'Man Chong', 'Mao Jie', 'Meng Da', 'Mi Fang', 'Mi Zhu', 'Pan Zhang', 'Pang De', 'Peng Yang', 'Qiao Zhou', 'Qin Mi', 'River Wei', 'Sima Yi', 'Sun Ce', 'Sun Qian', 'Sun Quan', 'Taishi Ci', 'Van Leader', 'Wang Lang', 'Wang Ping', 'Wei Yan', 'Wen Ping', 'Who Conquers', 'Who Guards', 'Who Wages', 'Wu Lan', 'Wu Yi', 'Xiahou Dun', 'Xiahou Yuan', 'Xu Chu', 'Xu Huang', 'Xu Jing', 'Xu Sheng', 'Xun Yu', 'Yan Yan', 'Yang Hong', 'Yangping Pass', 'Yi Ji', 'Yu Jin', 'Yuan Shao', 'Yuan Shu', 'Yue Jing', 'Zhang Bao', 'Zhang Fei', 'Zhang He', 'Zhang Liao', 'Zhang Lu', 'Zhang Xiu', 'Zhang Yi', 'Zhang Zhao', 'Zhao Yun', 'Zhou Cang', 'Zhou Qun', 'Zhou Tai', 'Zhou Yu', 'Zhuge Jin', 'Zhuge Liang', 'Zhuo Ying']

# %% [markdown]
# 几种社区检测算法均表现出非常非常非常差的效果。
# 可能的原因：我们采用在段落中共同出现作为两个角色具有社会关系的依据，这种社会关系可能包括敌对关系。比如诸葛亮和司马懿，共现频率很高，因而被分到了同一社区。

# %%
G_all.edges(data=True)
# Out:
# EdgeDataView([('Huangfu Song', 'Zhu Jun', {'weight': 6.0}), ('Huangfu Song', 'Zhang Lian', {'weight': 4.0}), ('Huangfu Song', 'Lu Zhi', {'weight': 4.0}), ('Huangfu Song', 'Liu Bei', {'weight': 3.0}), ('Huangfu Song', 'Cao Cao', {'weight': 2.0}), ('Huangfu Song', 'Zhang Ba', {'weight': 3.0}), ('Huangfu Song', 'Capital Luoyang', {'weight': 1.0}), ('Huangfu Song', 'Dong Zhuo', {'weight': 1.0}), ('Huangfu Song', 'Zhang Jue', {'weight': 1.0}), ('Huangfu Song', 'Li Su', {'weight': 1.0}), ('Huangfu Song', 'Li Jue', {'weight': 1.0}), ('Huangfu Song', 'Lu Bu', {'weight': 1.0}), ('Huangfu Song', 'Zhang Ji', {'weight': 1.0}), ('Huangfu Song', 'Guo Si', {'weight': 1.0}), ('Huangfu Song', 'Fan Chou', {'weight': 1.0}), ('Zhu Jun', 'Lu Zhi', {'weight': 3.0}), ('Zhu Jun', 'Liu Bei', {'weight': 7.0}), ('Zhu Jun', 'Zhang Lian', {'weight': 2.0}), ('Zhu Jun', 'Zhang Ba', {'weight': 3.0}), ('Zhu Jun', 'Han Zhong', {'weight': 2.0}), ('Zhu Jun', 'Sun Jian', {'weight': 1.0}), ('Zhu Jun', 'Sun Zi', {'weight': 1.0}), ('Zhu Jun', 'Liu Bang', {'weight': 1.0}), ('Zhu Jun', 'Sun Zhong', {'weight': 2.0}), ('Zhu Jun', 'Zhao Hong', {'weight': 2.0}), ('Zhu Jun', 'Zhang Rang', {'weight': 1.0}), ('Zhu Jun', 'Yan Zheng', {'weight': 1.0}), ('Zhu Jun', 'Zhao Zhong', {'weight': 1.0}), ('Zhu Jun', 'Guo Si', {'weight': 3.0}), ('Zhu Jun', 'Li Jue', {'weight': 1.0}), ('Zhu Jun', 'Yang Biao', {'weight': 3.0}), ('Zhu Jun', 'Yang Mi', {'weight': 1.0}), ('Zhang Lian', 'Lu Zhi', {'weight': 1.0}), ('Zhang Lian', 'Liu Bei', {'weight': 2.0}), ('Zhang Lian', 'Zhang Ba', {'weight': 5.0}), ('Zhang Lian', 'Cao Song', {'weight': 1.0}), ('Zhang Lian', 'Zhang Jiao', {'weight': 1.0}), ('Zhang Lian', 'Cao Cao', {'weight': 2.0}), ('Zhang Lian', 'Dong Zhuo', {'weight': 1.0}), ('Zhang Lian', 'Zhang Jue', {'weight': 1.0}), ('Zhang Lian', 'Capital Luoyang', {'weight': 1.0}), ('Lu Zhi', 'Zheng Xuan', {'weight': 1.0}), ('Lu Zhi', 'Dong Zhuo', {'weight': 2.0}), ('Lu Zhi', 'Zhang Ba', {'weight': 1.0}), ('Lu Zhi', 'Zhang Fei', {'weight': 1.0}), ('Lu Zhi', 'Zhou Jing', {'weight': 1.0}), ('Lu Zhi', 'Liu Bei', {'weight': 7.0}), ('Lu Zhi', 'Zhang Jiao', {'weight': 3.0}), ('Lu Zhi', 'Cao Cao', {'weight': 1.0}), ('Lu Zhi', 'Yi Yin', {'weight': 1.0}), ('Lu Zhi', 'Tai Jia', {'weight': 1.0}), ('Lu Zhi', 'Huo Guang', {'weight': 1.0}), ('Lu Zhi', 'Zheng Tai', {'weight': 1.0}), ('Liu Bei', 'Zheng Xuan', {'weight': 4.0}), ('Liu Bei', 'Liu Hong', {'weight': 2.0}), ('Liu Bei', 'Su Shuang', {'weight': 1.0}), ('Liu Bei', 'Zhang Jiao', {'weight': 1.0}), ('Liu Bei', 'Liu Yan', {'weight': 2.0}), ('Liu Bei', 'Cheng Yuanzhi', {'weight': 1.0}), ('Liu Bei', 'Liu Yuanqi', {'weight': 1.0}), ('Liu Bei', 'Zhang Ba', {'weight': 6.0}), ('Liu Bei', 'Zhang Fei', {'weight': 89.0}), ('Liu Bei', 'Zhang Shiping', {'weight': 1.0}), ('Liu Bei', 'Guan Yu', {'weight': 88.0}), ('Liu Bei', 'Zhou Jing', {'weight': 2.0}), ('Liu Bei', 'Dong Zhuo', {'weight': 5.0}), ('Liu Bei', 'Han Zhong', {'weight': 1.0}), ('Liu Bei', 'Sun Zhong', {'weight': 1.0}), ('Liu Bei', 'Zhang Ju', {'weight': 1.0}), ('Liu Bei', 'Sun Jian', {'weight': 1.0}), ('Liu Bei', 'Zhang Jun', {'weight': 1.0}), ('Liu Bei', 'Liu Hu', {'weight': 1.0}), ('Liu Bei', 'Zhao Hong', {'weight': 1.0}), ('Liu Bei', 'Liu Yu', {'weight': 2.0}), ('Liu Bei', 'Gao Sheng', {'weight': 1.0}), ('Liu Bei', 'Zhang Chun', {'weight': 1.0}), ('Liu Bei', 'Yuan Shao', {'weight': 22.0}), ('Liu Bei', 'Lu Bu', {'weight': 38.0}), ('Liu Bei', 'Gongsun Zan', {'weight': 2.0}), ('Liu Bei', 'Zhao Cen', {'weight': 1.0}), ('Liu Bei', 'Zhao Qi', {'weight': 1.0}), ('Liu Bei', 'Ma Midi', {'weight': 1.0}), ('Liu Bei', 'Cao Cao', {'weight': 121.0}), ('Liu Bei', 'Mi Zhu', {'weight': 12.0}), ('Liu Bei', 'Zhang Kai', {'weight': 1.0}), ('Liu Bei', 'Tao Qian', {'weight': 9.0}), ('Liu Bei', 'Taishi Ci', {'weight': 1.0}), ('Liu Bei', 'Guan Hai', {'weight': 1.0}), ('Liu Bei', 'Guo Jia', {'weight': 3.0}), ('Liu Bei', 'Cao Song', {'weight': 1.0}), ('Liu Bei', 'Tien Kai', {'weight': 1.0}), ('Liu Bei', 'Kong Rong', {'weight': 4.0}) ...
